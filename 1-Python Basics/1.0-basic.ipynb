# %%
#Pyhton is case sensitive

Name = "Debayudh"
name = "Roy"

print(Name)
print(name)
# Out:
# Debayudh
# Roy

# %% [markdown]
# ##Indentation is one of the most important thing in Python. It is used to define code structure and hierarchy of code.

# %%
age = 32
if age>30:
    print(age) #This is indentation

print(age)
# Out:
# 32
# 32

# %%
# Line Continuation
# Use a backslash (\) to continue a statement to the next line

total = 1+2+3+4+5+\
6+7+8

print(total)
# Out:
# 36

# %%
#Multiple statements on a single line

x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
#variable assigment
name = "Debayudh" #name is a string
age = 23 #age is an integer
print(type(age))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Type inference
var=10
print(type(var))
var="Debayudh"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ##Python variables are dynamically typed, that means type of the variables are decided at the runtime.

# %% [markdown]
# That was the basics
